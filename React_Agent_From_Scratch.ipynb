# %%
from openai import OpenAI
import openai, inspect
print("OpenAI class:", OpenAI)
print("openai module path:", openai.__file__)
import re

from dotenv import load_dotenv
_ = load_dotenv()
client = OpenAI()
# Out:
# OpenAI class: <class 'openai.OpenAI'>
# openai module path: /Users/mohammadmeftauddin/PycharmProjects/Feb16_BuildingAIAgents/.venv/lib/python3.9/site-packages/openai/__init__.py

# %%
class Agent:
    """
    A class representing an AI agent that can engage in conversations using OpenAI's API.
    """

    def __init__(self, system=""):
        """
        Initialize the agent with an optional system message.

        Args:
            system (str): The system message to set the context for the agent.
        """
        self.system = system
        self.messages = []
        if self.system:
            # If a system message is provided, add it to the message history
            self.messages.append({"role": "system", "content": system})

    def __call__(self, message):
        """
        Allow the agent to be called directly with a message.

        Args:
            message (str): The user's input message.

        Returns:
            str: The agent's response to the input message.
        """
        # Add the user's message to the conversation history
        self.messages.append({"role": "user", "content": message})
        # Execute the conversation and get the result
        result = self.execute()
        # Add the assistant's response to the conversation history
        self.messages.append({"role": "assistant", "content": result})
        return result

    def execute(self):
        """
        Execute the conversation by sending the entire conversation history to the OpenAI API.

        Returns:
            str: The content of the model's response.
        """
        # Send the entire conversation history to the OpenAI API
        completion = client.chat.completions.create(
                        model="gpt-4o-mini",
                        temperature=0,
                        messages=self.messages)
        # Return the content of the model's response
        return completion.choices[0].message.content

# %%
import sys, pkgutil
print(sys.executable)
print("openai installed?", pkgutil.find_loader("openai") is not None)
# Out:
# /Users/mohammadmeftauddin/PycharmProjects/Feb16_BuildingAIAgents/.venv/bin/python
# openai installed? True

# %%
from openai import OpenAI
import openai, inspect
print("OpenAI class:", OpenAI)
print("openai module path:", openai.__file__)
# Out:
# OpenAI class: <class 'openai.OpenAI'>
# openai module path: /Users/mohammadmeftauddin/PycharmProjects/Feb16_BuildingAIAgents/.venv/lib/python3.9/site-packages/openai/__init__.py

# %% [markdown]
# Defining the Agent's Prompt and Behavior
# We define a prompt that sets the context and behavior for the agent. The agent operates in a loop of Thought, Action, PAUSE, and Observation, and finally outputs an Answer.

# %%
# Define a prompt for the agent
prompt = """
You run in a loop of Thought, Action, PAUSE, Observation.
At the end of the loop you output an Answer.
Use Thought to describe your thoughts about the question you have been asked.
Use Action to run one of the actions available to you - then return PAUSE.
Observation will be the result of running those actions.

Your available actions are:

calculate_total_price:
e.g. calculate_total_price: apple: 2, banana: 3
Runs a calculation for the total price based on the quantity and prices of the fruits.

get_fruit_price:
e.g. get_fruit_price: apple
returns the price of the fruit when given its name.

Example session:

Question: What is the total price for 2 apples and 3 bananas?
Thought: I should calculate the total price by getting the price of each fruit and summing them up.
Action: get_fruit_price: apple
PAUSE

Observation: The price of an apple is $1.5.

Action: get_fruit_price: banana
PAUSE

Observation: The price of a banana is $1.2.

Action: calculate_total_price: apple: 2, banana: 3
PAUSE

You then output:

Answer: The total price for 2 apples and 3 bananas is $6.6.
""".strip()

# %% [markdown]
# Defining Available Actions
# We define functions that the agent can use to perform actions:

# %%
# Price lookup for fruits
fruit_prices = {
    "apple": 1.5,
    "banana": 1.2,
    "orange": 1.3,
    "grapes": 2.0
}

# Function to calculate the price of a specific fruit
def get_fruit_price(fruit):
    if fruit in fruit_prices:
        return f"The price of a {fruit} is ${fruit_prices[fruit]}"
    else:
        return f"Sorry, I don't know the price of {fruit}."

# Function to calculate total price based on quantities
def calculate_total_price(fruits):
    total = 0.0
    fruit_list = fruits.split(", ")
    for item in fruit_list:
        fruit, quantity = item.split(": ")
        quantity = int(quantity)
        if fruit in fruit_prices:
            total += fruit_prices[fruit] * quantity
        else:
            return f"Sorry, I don't have the price of {fruit}."
    return f"The total price is ${total:.2f}"

# Mapping actions to functions
known_actions = {
    "get_fruit_price": get_fruit_price,
    "calculate_total_price": calculate_total_price
}

# %% [markdown]
# Creating the Agent Instance
# We create an instance of the Agent class with the defined prompt.

# %%
react_agent = Agent(system=prompt)

# %%
# Run a query
action_re = re.compile(r'^Action: (\w+): (.*)$')   # python regular expression to select action

def query(question):
    bot = Agent(prompt)
    result = bot(question)
    print(result)
    actions = [
        action_re.match(a)
        for a in result.split('\n')
        if action_re.match(a)
    ]
    if actions:
        action, action_input = actions[0].groups()
        if action not in known_actions:
            raise Exception(f"Unknown action: {action}: {action_input}")
        print(f" -- running {action} {action_input}")
        observation = known_actions[action](action_input)
        print("Observation:", observation)
    else:
        return

# %%
query("What is the price of a banana?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 query("What is the price of a banana?")
#
# Cell In[24], line 6, in query(question)
#       4 def query(question):
#       5     bot = Agent(prompt)
# ----> 6     result = bot(question)
#       7     print(result)
#       8     actions = [
#       9         action_re.match(a)
#      10         for a in result.split('\n')
#      11         if action_re.match(a)
#      12     ]
#
# Cell In[19], line 32, in Agent.__call__(self, message)
#      30 self.messages.append({"role": "user", "content": message})
#      31 # Execute the conversation and get the result
# ---> 32 result = self.execute()
#      33 # Add the assistant's response to the conversation history
#      34 self.messages.append({"role": "assistant", "content": result})
#
# Cell In[19], line 45, in Agent.execute(self)
#      38 """
#      39 Execute the conversation by sending the entire conversation history to the OpenAI API.
#      40
#      41 Returns:
#      42     str: The content of the model's response.
#      43 """
#      44 # Send the entire conversation history to the OpenAI API
# ---> 45 completion = client.chat.completions.create(
#      46                 model="gpt-4o-mini",
#      47                 temperature=0,
#      48                 messages=self.messages)
#      49 # Return the content of the model's response
#      50 return completion.choices[0].message.content
#
# File ~/PycharmProjects/Feb16_BuildingAIAgents/.venv/lib/python3.9/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/PycharmProjects/Feb16_BuildingAIAgents/.venv/lib/python3.9/site-packages/openai/resources/chat/completions/completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)
#    1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~/PycharmProjects/Feb16_BuildingAIAgents/.venv/lib/python3.9/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/PycharmProjects/Feb16_BuildingAIAgents/.venv/lib/python3.9/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

resp = client.chat.completions.create(
    model="gpt-oss:120b-cloud",   # cloud-backed via Ollama
    messages=[{"role": "user", "content": "Explain JWT audience validation in Spring Security."}],
)

print(resp.choices[0].message.content)
# Out:
# ## JWT Audience (`aud`) Validation in Spring Security
# Spring Security (the part that implements an **OAuth 2.0 Resource Server**) can decode, verify and turn a JSON Web Token (JWT) into an `Authentication` object.
# One of the checks you normally want to run on a JWT is **audience validation** – i.e. “Is this token intended for *my* API?”
#
# Below you will find:
#
# | Section | What it covers |
# |---------|-----------------|
# | 1️⃣ What the `aud` claim is and why you care | Conceptual overview |
# | 2️⃣ How Spring Security does validation by default | Built‑in validators |
# | 3️⃣ Configuring audience validation with **Boot properties** | “Zero‑code” approach |
# | 4️⃣ Fine‑grained custom audience validation (Java config) | Full‑control, multiple audiences, etc. |
# | 5️⃣ Putting it together with `HttpSecurity` | Resource‑server DSL |
# | 6️⃣ Common pitfalls & troubleshooting | “Gotchas” you’ll run into |
# | 7️⃣ Testing the audience validator | `MockMvc` + `@JwtTest` convenience |
# | 8️⃣ Full example project layout | Ready‑to‑run skeleton |
#
# ---
#
# ## 1️⃣ What the `aud` Claim Is – and Why You Must Validate It
#
# | JWT Claim | Typical type | Meaning for an API |
# |-----------|--------------|--------------------|
# | `iss`     | String (URL) | Who issued the token (identity provider). |
# | `sub`     | String       | The subject (user or client) the token represents. |
# | `aud`     | String **or** array of strings | **Audience** – one or more identifiers that the token is *intended for*. |
# | `exp`     | NumericDate  | Expiration time. |
#
# *Why validate `aud`?*
#
# 1. **Prevent token replay** – A token issued for Service A should not be accepted by Service B.
# 2. **Support multi‑tenant APIs** – Different tenants can be represented by different audience values.
# 3. **Compliance with the JWT spec** – RFC 7519 §4.1.3 says the audience *MUST* be checked by the recipient.
#
# If the token’s `aud` claim does **not** contain a value that matches *your* service identifier, you must reject the request with **401 Unauthorized** (or **403 Forbidden** if you want to be explicit).
#
# ---
#
# ## 2️⃣ How Spring Security Validates JWTs By Default
#
# Spring Security’s **resource‑server** support works through a `JwtDecoder`. The decoder produces a `Jwt` (a `Map<String, Object>`‑like object) and then runs a **chain of `OAuth2TokenValidator<Jwt>`** instances.
#
# Out‑of‑the‑box:
#
# | Validator | When it’s added automatically |
# |-----------|--------------------------------|
# | `JwtTimestampValidator` | Checks `exp` and `nbf`. |
# | `JwtIssuerValidator` | Added **only** if you configure `spring.security.oauth2.resourceserver.jwt.issuer-uri`. |
# | `JwtClaimValidator` for `aud` | Added **only** if you configure `spring.security.oauth2.resourceserver.jwt.audience`. *(Boot 3 / Spring Security 6 introduced this convenient property.)* |
#
# If you **don’t** set any of those properties, Spring simply validates the signature (via JWK set) and timestamps – it **does not** look at `iss` or `aud`.
#
# > **Bottom line:** *You have to tell Spring which audience you expect, either via Boot property or by wiring a custom validator.*
#
# ---
#
# ## 3️⃣ Zero‑code Audience Validation with Spring Boot Properties
#
# ### 3.1 Add the starter
#
# ```xml
# <!-- pom.xml -->
# <dependency>
#     <groupId>org.springframework.boot</groupId>
#     <artifactId>spring-boot-starter-oauth2-resource-server</artifactId>
# </dependency>
# ```
#
# ### 3.2 Application properties (Boot 3+)
#
# ```yaml
# # application.yml
# spring:
#   security:
#     oauth2:
#       resourceserver:
#         jwt:
#           # 1️⃣ JWK set location – either issuer‑uri (auto‑discovery) or a raw jwk‑set‑uri
#           issuer-uri: https://login.example.com/realms/myrealm   # <‑ tell Spring to also validate iss
#           # 2️⃣ Expected audience(s) – a list; Spring will generate a JwtValidator that checks
#           audience: my-api
#           # You can also set a list:
#           # audience:
#           #   - my-api
#           #   - my-legacy-api
# ```
#
# *What happens under the hood?*
#
# `JwtDecoders.fromIssuerLocation(issuer)` builds a `NimbusJwtDecoder`. Spring then adds a **default validator chain**:
#
# ```java
# JwtValidators.createDefaultWithIssuer(issuer)
#     .andThen(new JwtClaimValidator<List<String>>("aud",
#         aud -> aud != null && aud.contains("my-api")))
# ```
#
# If you only need audience validation **and not** issuer validation, just supply a `jwk-set-uri`:
#
# ```yaml
# spring:
#   security:
#     oauth2:
#       resourceserver:
#         jwt:
#           jwk-set-uri: https://login.example.com/realms/myrealm/protocol/openid-connect/certs
#           audience: my-api
# ```
#
# That is the *simplest* way to enforce that a token contains `"my-api"` (or any element of the list) in its `aud` claim.
#
# ---
#
# ## 4️⃣ Full‑Control Custom Audience Validation (Java Config)
#
# Sometimes you need more flexibility:
#
# * multiple acceptable audience values (including a fallback)
# * case‑insensitive comparison
# * support for both a string and an array representation
# * logging / metrics on validation failures
#
# ### 4.1 Define a bean for the `JwtDecoder`
#
# ```java
# @Configuration
# public class JwtConfig {
#
#     @Value("${jwt.jwk-set-uri}")
#     private String jwkSetUri;
#
#     @Value("${jwt.expected-audiences}")
#     private List<String> expectedAudiences;   // e.g. ["my-api", "my-legacy-api"]
#
#     @Bean
#     JwtDecoder jwtDecoder() {
#         NimbusJwtDecoder decoder = NimbusJwtDecoder.withJwkSetUri(this.jwkSetUri).build();
#
#         // 1️⃣ Timestamp validator (exp, nbf) – always present
#         OAuth2TokenValidator<Jwt> timestampValidator = new JwtTimestampValidator();
#
#         // 2️⃣ Optional issuer validator (if you also care)
#         OAuth2TokenValidator<Jwt> issuerValidator = JwtValidators.createDefault();
#
#         // 3️⃣ **Custom audience validator**
#         OAuth2TokenValidator<Jwt> audienceValidator = new JwtClaimValidator<>(
#                 "aud",
#                 aud -> {
#                     // `aud` may be a String or a Collection<String>
#                     if (aud instanceof String s) {
#                         return expectedAudiences.contains(s);
#                     }
#                     if (aud instanceof Collection<?> coll) {
#                         return coll.stream()
#                                    .filter(String.class::isInstance)
#                                    .map(String.class::cast)
#                                    .anyMatch(expectedAudiences::contains);
#                     }
#                     return false;
#                 });
#
#         // 4️⃣ Combine everything (order matters – first failure short‑circuits)
#         OAuth2TokenValidator<Jwt> validator =
#                 new DelegatingOAuth2TokenValidator<>(timestampValidator, issuerValidator, audienceValidator);
#
#         decoder.setJwtValidator(validator);
#         return decoder;
#     }
# }
# ```
#
# ### 4.2 Using a `JwtAuthenticationConverter` (optional)
#
# Often you also want to turn a custom claim (e.g. `roles` or `scope`) into GrantedAuthorities:
#
# ```java
# @Bean
# JwtAuthenticationConverter jwtAuthenticationConverter() {
#     JwtAuthenticationConverter conv = new JwtAuthenticationConverter();
#     conv.setJwtGrantedAuthoritiesConverter(jwt -> {
#         Collection<String> scopes = jwt.getClaimAsStringList("scope");
#         return scopes == null ? Collections.emptyList()
#                 : scopes.stream()
#                         .map(s -> new SimpleGrantedAuthority("SCOPE_" + s))
#                         .collect(Collectors.toList());
#     });
#     return conv;
# }
# ```
#
# You’ll plug both beans into the HTTP security DSL (next section).
#
# ---
#
# ## 5️⃣ Hooking It All Up With `HttpSecurity`
#
# ```java
# @EnableWebSecurity
# @Configuration(proxyBeanMethods = false)
# public class SecurityConfig {
#
#     private final JwtDecoder jwtDecoder;
#     private final JwtAuthenticationConverter jwtAuthConverter;
#
#     public SecurityConfig(JwtDecoder jwtDecoder,
#                           JwtAuthenticationConverter jwtAuthConverter) {
#         this.jwtDecoder = jwtDecoder;
#         this.jwtAuthConverter = jwtAuthConverter;
#     }
#
#     @Bean
#     SecurityFilterChain securityFilterChain(HttpSecurity http) throws Exception {
#         http
#             // --------------------------------------------------------------
#             // 1️⃣ Disable stateful stuff for a pure resource server
#             // --------------------------------------------------------------
#             .csrf(csrf -> csrf.disable())
#             .sessionManagement(sess -> sess.sessionCreationPolicy(
#                     SessionCreationPolicy.STATELESS))
#
#             // --------------------------------------------------------------
#             // 2️⃣ Configure OAuth2 Resource Server with our custom decoder
#             // --------------------------------------------------------------
#             .oauth2ResourceServer(oauth2 -> oauth2
#                     .jwt(jwt -> jwt
#                             .decoder(this.jwtDecoder)
#                             .jwtAuthenticationConverter(this.jwtAuthConverter))
#             )
#             // --------------------------------------------------------------
#             // 3️⃣ Authorize requests (example)
#             // --------------------------------------------------------------
#             .authorizeHttpRequests(authz -> authz
#                     .requestMatchers(HttpMethod.GET, "/public/**").permitAll()
#                     .requestMatchers(HttpMethod.GET, "/admin/**").hasRole("ADMIN")
#                     .anyRequest().authenticated()
#             );
#
#         return http.build();
#     }
# }
# ```
#
# **Key points**
#
# * `jwt.decoder(...)` tells Spring to use the **custom decoder** that already contains the audience validator.
# * If you rely solely on Boot properties, you can drop the `decoder(...)` call; Spring will auto‑wire the default decoder with the built‑in validators.
# * The `jwtAuthenticationConverter` is optional but often useful for role/authority mapping.
#
# ---
#
# ## 6️⃣ Common Pitfalls & How to Fix Them
#
# | Symptom | Likely cause | Fix |
# |---------|--------------|-----|
# | **401 – “Invalid JWT token”** (debug log shows “The Claim 'aud' is not present”) | Audience claim is missing *or* you configured a validator that expects a collection while the token supplies a plain string (or vice‑versa). | Make the validator accept both `String` and `Collection`. See the example in §4.1. |
# | **401 – “Invalid JWT token”** (log: `aud` claim does not contain expected value) | Token includes multiple audiences, but you only provided one string in the validator. | Use `JwtClaimValidator<List<String>>` and compare with `containsAll` / `anyMatch`. |
# | **500 – “Failed to resolve JWK Set”** | `jwk-set-uri` is wrong, or the IdP’s JWKS endpoint requires authentication. | Verify the URL in the browser, or use the `issuer-uri` (auto‑discovery) if possible. |
# | **Auditing “aud” does not get checked even though you set the property** | You have two `JwtDecoder` beans – Spring picks the one without the audience validator. | Ensure there is **only one** `JwtDecoder` bean (remove manual bean or annotate with `@Primary`). |
# | **Token passes even though audience is wrong** | You inadvertently disabled the default validator chain by calling `decoder.setJwtValidator(null)` or by returning `JwtDecoder` bean **without** adding the validator. | Never set the validator to `null`. Add the audience validator via `DelegatingOAuth2TokenValidator`. |
# | **Multiple audience values but only one matches** | Your validator uses `equals` instead of `contains`. | Use `aud -> expectedAudiences.stream().anyMatch(aud::contains)` (or the collection‑aware version). |
# | **Aud claim is a single string but you passed a List in `application.yml`** | Spring’s auto‑validator expects the claim to be a collection (list). It will still work because the validator internally checks `instanceof Collection`; but older versions (<6.0) required the claim to be an array. | Upgrade to Spring Security 6.0+; otherwise write a custom validator as shown in §4.1. |
#
# ### Logging the validation process
#
# Add a logger to the custom validator to see why it fails:
#
# ```java
# private static final Logger log = LoggerFactory.getLogger(AudienceValidator.class);
#
# OAuth2TokenValidator<Jwt> audienceValidator = (jwt) -> {
#     Object aud = jwt.getClaim("aud");
#     boolean ok = checkAud(aud);
#     if (!ok) {
#         log.warn("JWT audience validation failed – token aud: {} – expected: {}",
#                  aud, expectedAudiences);
#         return OAuth2TokenValidatorResult.failure(
#                 new OAuth2Error("invalid_token", "Invalid audience", null));
#     }
#     return OAuth2TokenValidatorResult.success();
# };
# ```
#
# ---
#
# ## 7️⃣ Testing the Audience Validator
#
# Spring Boot makes it easy to test the security filter chain with `MockMvc`. Below is a tiny test harness that generates a signed token using a **test RSA key** (or you can read a token from a fixture).
#
# ### 7.1 Test configuration
#
# ```java
# @SpringBootTest
# @AutoConfigureMockMvc
# class AudienceValidatorTests {
#
#     @Autowired MockMvc mvc;
#
#     // A tiny RSA key pair just for tests
#     private static final KeyPair TEST_KEY_PAIR = Keys.keyPairFor(SignatureAlgorithm.RS256);
#
#     private String token(String... audiences) {
#         Map<String, Object> claims = new HashMap<>();
#         claims.put("aud", audiences.length == 1 ? audiences[0] : List.of(audiences));
#
#         return Jwts.builder()
#                 .setHeaderParam(Header.TYPE, Header.JWT_TYPE)
#                 .setIssuer("https://login.example.com/realms/myrealm")
#                 .setSubject("user123")
#                 .addClaims(claims)
#                 .setExpiration(Date.from(Instant.now().plus(1, ChronoUnit.HOURS)))
#                 .signWith(TEST_KEY_PAIR.getPrivate(), SignatureAlgorithm.RS256)
#                 .compact();
#     }
#
#     @Test
#     void whenAudienceMatches_thenOk() throws Exception {
#         String jwt = token("my-api");
#
#         mvc.perform(get("/admin/dashboard")
#                         .header(HttpHeaders.AUTHORIZATION, "Bearer " + jwt))
#            .andExpect(status().isOk());
#     }
#
#     @Test
#     void whenAudienceDoesNotMatch_thenUnauthorized() throws Exception {
#         String jwt = token("other-api");
#
#         mvc.perform(get("/admin/dashboard")
#                         .header(HttpHeaders.AUTHORIZATION, "Bearer " + jwt))
#            .andExpect(status().isUnauthorized());
#     }
# }
# ```
#
# > **Tip:** If you use the auto‑configuration (`spring.security.oauth2.resourceserver.jwt.*`), you’ll also need a `NimbusJwtDecoder` bean that trusts the test key. The simplest way is to create a `JwtDecoder` bean **only in the test profile**:
#
# ```java
# @TestConfiguration
# static class TestJwtConfig {
#     @Bean
#     JwtDecoder jwtDecoder() {
#         return NimbusJwtDecoder.withPublicKey(TEST_KEY_PAIR.getPublic()).build();
#     }
# }
# ```
#
# Now the test runs against the exact validator logic you configured in production.
#
# ---
#
# ## 8️⃣ Full Example Project Skeleton
#
# ```
# src/
#  └─ main/
#      ├─ java/
#      │   └─ com.example.demo/
#      │       ├─ DemoApplication.java
#      │       ├─ config/
#      │       │   ├─ JwtConfig.java          // custom decoder & validator
#      │       │   └─ SecurityConfig.java      // HttpSecurity DSL
#      │       └─ controller/
#      │           └─ AdminController.java
#      └─ resources/
#          ├─ application.yml          # Boot props (issuer-uri + audience)
#          └─ static/ (optional)
# ```
#
# ### `DemoApplication.java`
#
# ```java
# @SpringBootApplication
# public class DemoApplication {
#     public static void main(String[] args) {
#         SpringApplication.run(DemoApplication.class, args);
#     }
# }
# ```
#
# ### `AdminController.java`
#
# ```java
# @RestController
# @RequestMapping("/admin")
# public class AdminController {
#
#     @GetMapping("/dashboard")
#     public ResponseEntity<String> dashboard(Authentication auth) {
#         return ResponseEntity.ok("Hello " + auth.getName() + ", you have ADMIN access");
#     }
# }
# ```
#
# ### `application.yml` (production)
#
# ```yaml
# server:
#   port: 8080
#
# spring:
#   security:
#     oauth2:
#       resourceserver:
#         jwt:
#           issuer-uri: https://login.example.com/realms/myrealm
#           audience: my-api
#           # If you prefer JWK‑set URI instead of issuer‑discovery:
#           # jwk-set-uri: https://login.example.com/realms/myrealm/protocol/openid-connect/certs
# ```
#
# ### `JwtConfig.java` (custom, optional – override if you need more control)
#
# ```java
# @Configuration
# @RequiredArgsConstructor
# public class JwtConfig {
#
#     @Value("${jwt.expected-audiences}")
#     private List<String> expectedAudiences; // pulled from a custom property
#
#     @Bean
#     JwtDecoder jwtDecoder(@Value("${jwt.jwk-set-uri}") String jwkUri) {
#         NimbusJwtDecoder decoder = NimbusJwtDecoder.withJwkSetUri(jwkUri).build();
#
#         // combine default timestamp validator with our audience validator
#         OAuth2TokenValidator<Jwt> validator = new DelegatingOAuth2TokenValidator<>(
#                 new JwtTimestampValidator(),
#                 new JwtClaimValidator<>("aud", aud -> {
#                     if (aud instanceof String s) {
#                         return expectedAudiences.contains(s);
#                     }
#                     if (aud instanceof Collection<?> coll) {
#                         return coll.stream()
#                                    .filter(String.class::isInstance)
#                                    .map(String.class::cast)
#                                    .anyMatch(expectedAudiences::contains);
#                     }
#                     return false;
#                 })
#         );
#
#         decoder.setJwtValidator(validator);
#         return decoder;
#     }
# }
# ```
#
# > **Note:** The example above shows two ways to configure audience validation – **property‑driven** (simpler) or **bean‑driven** (more flexible). Choose whichever matches your needs.
#
# ---
#
# ## TL;DR – What You Must Do
#
# | Goal | Minimal steps |
# |------|----------------|
# | **Enforce audience without code** | ```yaml spring.security.oauth2.resourceserver.jwt.audience: my-api ``` (plus either `issuer-uri` or `jwk-set-uri`). |
# | **Custom audience logic (multiple values, case‑insensitive, logging)** | 1️⃣ Provide a `JwtDecoder` bean. <br>2️⃣ Add a `JwtClaimValidator` that inspects `aud` as `String` or `Collection`. <br>3️⃣ Wire the decoder into the `HttpSecurity` DSL (`oauth2ResourceServer().jwt().decoder(myDecoder)`). |
# | **Unit test it** | Use `MockMvc`, generate a JWT with the claim(s) you want, and assert `200` vs `401`. |
#
# With those pieces in place, your Spring Security‑protected API will only accept JWTs whose `aud` claim matches the value(s) you have declared – protecting you from token‑replay attacks and ensuring each service only consumes the tokens that were meant for it. Happy coding!

# %%
import os
from langchain_openai import ChatOpenAI

# Fake key because the OpenAI client requires it (Ollama ignores it completely)
os.environ["OPENAI_API_KEY"] = "ollama"

# Point the OpenAI-compatible client to Ollama instead of api.openai.com
os.environ["OPENAI_BASE_URL"] = "http://localhost:11434/v1"

# Create the LLM using Ollama's model name
llm = ChatOpenAI(
    model="gpt-oss:120b-cloud",    # using the 8B model
    temperature=0.2,
)

# Quick test call (optional)
resp = llm.invoke("Say 'hello from PyCharm + Ollama + LangGraph setup!'")
print(resp.content)
# Out:
# hello from PyCharm + Ollama + LangGraph setup!

# %%
import ssl
print(ssl.OPENSSL_VERSION)
# Out:
# LibreSSL 2.8.3
